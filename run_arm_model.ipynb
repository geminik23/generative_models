# %%
from pydoc import describe
import torch
from torch.utils.data import DataLoader, random_split
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from common import train_gen_network, get_digit_dataset, get_fashion_dataset
from arm_model import AutoregressiveModel, create_network
from common import plot_digit_imgs
import os
result_dir = 'results'
if not(os.path.exists(result_dir)):
    os.mkdir(result_dir)

# %%
IMG_SIZE = 12
DIM = IMG_SIZE*IMG_SIZE # dimension 8*8
NUM_CLASS = 16 # value range 0-15
HIDDEN_DIM = 256
LEARNING_RATE = 1e-3
EPOCH = 500
KERNEL_SIZE = IMG_SIZE-1 # almost width or height length
BATCH_SIZE = 64
MAX_PATIENCE = 20
plot_func = lambda x: plot_digit_imgs(x, IMG_SIZE, (4, 4))

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
dataset = get_digit_dataset(IMG_SIZE, NUM_CLASS)
val_len = int(len(dataset)*0.05)
train_dataset, val_dataset = random_split(dataset, [len(dataset) - val_len, val_len])
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)

# %%
model = AutoregressiveModel(create_network(HIDDEN_DIM, NUM_CLASS, KERNEL_SIZE, 3), DIM, NUM_CLASS).to(device)
optimizer = torch.optim.Adamax(model.parameters(), LEARNING_RATE)

# %%
results = train_gen_network(os.path.join(result_dir,"arm_e_{}.pt"), model, MAX_PATIENCE, train_loader, val_loader, EPOCH, device, optimizer=optimizer, plot_func=plot_func, plot_img_interval=10)
results = pd.DataFrame(results)
# Out:
# Epoch:   0%|          | 0/500 [00:00<?, ?it/s]
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 1 - val_loss=1.433504045009613
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 2 - val_loss=1.003601849079132
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 3 - val_loss=0.8599170744419098
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 4 - val_loss=0.8192593157291412
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 5 - val_loss=0.7914299368858337
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 6 - val_loss=0.7731370627880096
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 7 - val_loss=0.7580636143684387
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 8 - val_loss=0.7501066029071808
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 9 - val_loss=0.7420499622821808
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 10 - val_loss=0.7299202680587769
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 11 - val_loss=0.7218801081180573
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 12 - val_loss=0.7116658389568329
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 13 - val_loss=0.7098096907138824
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 14 - val_loss=0.6981247961521149
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 15 - val_loss=0.7022014260292053
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 16 - val_loss=0.6903304755687714
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 17 - val_loss=0.684259295463562
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 18 - val_loss=0.681685596704483
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 19 - val_loss=0.6785003244876862
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 20 - val_loss=0.6759758293628693
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 21 - val_loss=0.6711270809173584
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 22 - val_loss=0.668385922908783
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 23 - val_loss=0.6682696044445038
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 24 - val_loss=0.6618663668632507
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 25 - val_loss=0.6631979942321777
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 26 - val_loss=0.6653569340705872
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 27 - val_loss=0.6628410816192627
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 28 - val_loss=0.6617498993873596
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 29 - val_loss=0.655344158411026
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 30 - val_loss=0.651240348815918
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 31 - val_loss=0.6501668393611908
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 32 - val_loss=0.64808589220047
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 33 - val_loss=0.6494345366954803
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 34 - val_loss=0.6493890285491943
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 35 - val_loss=0.6487208902835846
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 36 - val_loss=0.6666387915611267
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 37 - val_loss=0.6542965769767761
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 38 - val_loss=0.6439196765422821
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 39 - val_loss=0.6485292315483093
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 40 - val_loss=0.6460986733436584
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 41 - val_loss=0.6546821594238281
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 42 - val_loss=0.6449573040008545
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 43 - val_loss=0.6476296484470367
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 44 - val_loss=0.6440301239490509
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 45 - val_loss=0.6524066925048828
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 46 - val_loss=0.6484565734863281
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 47 - val_loss=0.6529977023601532
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 48 - val_loss=0.6462461054325104
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 49 - val_loss=0.6497244536876678
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 50 - val_loss=0.652738481760025
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 51 - val_loss=0.6541528403759003
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 52 - val_loss=0.6674081981182098
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 53 - val_loss=0.6747832298278809
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 54 - val_loss=0.66212597489357
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 55 - val_loss=0.6630448698997498
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 56 - val_loss=0.6745763421058655
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 57 - val_loss=0.6721771359443665
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 58 - val_loss=0.6698331236839294
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# Validating:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 59 - val_loss=0.6739327609539032

# %%
sns.lineplot(x="epoch", y="val loss", data=results)
plt.show()

# %%
model = torch.load(os.path.join(result_dir, 'arm_e_38.pt'))
## GENERATE THE IMGS

imgs = model.inference(16, device).detach().cpu()
plot_digit_imgs(imgs, IMG_SIZE, (4,4))
